# %% [markdown]
# # ДЗ 2
#
# pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# грузим данные
df = pd.read_csv('S02-hw-dataset.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## пропуски и дубликаты

# %%
# смотрим где пропуски
df.isna().sum()

# %%
# дубликаты
df.duplicated().sum()

# %%
# какие-то странные значения
# отрицательные покупки
df[df['purchases'] < 0]

# %%
# возраст больше 100 или меньше 18 
df[(df['age'] > 100) | (df['age'] < 18)]

# %% [markdown]
# в данных есть неточности - пропуски в age, один дубликат, отрицательные purchases и странный возраст типа 120 лет или 5 лет

# %% [markdown]
# ## eda рад

# %%
# сколько юзеров по странам
df['country'].value_counts()

# %%
# группируем по странам
df.groupby('country').agg({
    'purchases': 'sum',
    'revenue': ['sum', 'mean']
})

# %%
# возрастные группы
df['age_group'] = pd.cut(df['age'], bins=[0, 25, 35, 50, 150], labels=['молодые', 'средние', 'старше', '50+'])
df.groupby('age_group')['revenue'].mean()

# %% [markdown]
# больше всего юзеров из FR и RU. по деньгам лучше всего DE хотя там меньше людей

# %% [markdown]
# ## графики

# %%
# гистограмма возраста
plt.figure(figsize=(10, 6))
plt.hist(df['age'].dropna(), bins=15, color='blue', alpha=0.7)
plt.xlabel('возраст')
plt.ylabel('количество')
plt.title('распределение по возрасту')
plt.savefig('figures/age_hist.png')
plt.show()

# %%
# боксплот
plt.figure(figsize=(10, 6))
df.boxplot(column='revenue', by='country')
plt.xlabel('страна')
plt.ylabel('revenue')
plt.title('доход по странам')
plt.suptitle('')
plt.savefig('figures/revenue_box.png')
plt.show()

# %%
# скаттер
plt.figure(figsize=(10, 6))
for country in df['country'].unique():
    data = df[df['country'] == country]
    plt.scatter(data['purchases'], data['revenue'], label=country, alpha=0.6)
plt.xlabel('покупки')
plt.ylabel('revenue')
plt.title('покупки vs доход')
plt.legend()
plt.savefig('figures/scatter.png')
plt.show()

# %% [markdown]
# график показывает что чем больше покупок тем больше денег
